# %% [markdown]
# <a href="https://colab.research.google.com/github/mdkamrulhasan/gvsu_machine_learning/blob/main/notebooks/assignment_2_startup_code_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning Assignment (2) Notebook (Startup Code)
#
# This notebook contains two tasks:
#
# ## Task 1: Gradient Descent for Second-Degree Polynomial Regression
# ## Task 2: Classification with Logistic Regression and Random Forest
#
# Complete both sections below.

# %% [markdown]
# =====================================================
#
# TASK 1: Polynomial Regression using Gradient Descent
# =====================================================
#
# You will:
# - Derive gradients manually
# - Implement gradient descent
# - Analyze convergence behavior

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
url = "https://raw.githubusercontent.com/mdkamrulhasan/data-public/main/miscellaneous/third_degree_polynomial_regression_data.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    x_0       x_1       x_2       x_3         y
# 0  1.0 -0.970478  0.941828 -0.914023  1.221212
# 1  1.0 -0.868166  0.753712 -0.654347 -2.271333
# 2  1.0 -1.909401  3.645812 -6.961317  3.964091
# 3  1.0  0.730079  0.533015  0.389143 -1.182732
# 4  1.0  0.077110  0.005946  0.000458 -1.645366

# %% [markdown]
# ## Prepare Data
#
# 🔹 Extract x and y as NumPy arrays.

# %%
# TODO
x_0 = None
x_1 = None
x_2 = None
x_3 = None
y = None
n = None
print("Number of samples:", n)
# Out:
# Number of samples: None

# %% [markdown]
# ## Initialize Parameters

# %%
beta_0 = 0.0
beta_1 = 0.0
beta_2 = 1.0
beta_3 = 1.0

learning_rate = 0.0001

print(beta_0, beta_1, beta_2, beta_3)

# %% [markdown]
# ## Model Prediction

# %%
def predict(x, b0, b1, b2, b3):
    # TODO
    pass

# %% [markdown]
# ## Loss Function

# %%
def compute_loss(x, y, b0, b1, b2, b3):
    y_hat = predict(x, b0, b1, b2, b3)

    # TODO

initial_loss = compute_loss(x, y, beta_0, beta_1, beta_2, beta_3)
print("Initial Loss =", initial_loss)

# %% [markdown]
# ## Gradient Derivation

# %%
def compute_gradients(x, y, b0, b1, b2, b3):
    # TODO (estimate model error)

    # Update Gradients
    d_b0 = None
    d_b1 = None
    d_b2 = None
    d_b3 = None
    return d_b0, d_b1, d_b2, d_b3

# %% [markdown]
# ## Gradient Descent Loop

# %%
iterations = 3
loss_history = []

for i in range(iterations):
    # TODO
    pass

# %% [markdown]
# ## Analysis & Reporting

# %%
# TODO

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# =====================================================
#
# TASK 2: Logistic Regression and Random Forest
# =====================================================

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


RANDOM_STATE = 42

# %% [markdown]
# ## Load Classification Dataset

# %%
url = "https://raw.githubusercontent.com/mdkamrulhasan/data-public/main/miscellaneous/adult_income_binary_processed.csv"
data = pd.read_csv(url)
data.head()

# %% [markdown]
# ## Train-Test Split

# %%
# TODO
X = None
y = None
X_train, X_test, y_train, y_test = None

# %% [markdown]
# ## Feature Encoding and Scaling

# %%
# TODO

# %% [markdown]
# ## Logistic Regression GridSearch

# %%
# HP Search for k-nn
param_grid_knn = {
     'knn__n_neighbors': [3, 5, 10, 20, 30]
}

grid_search_knn = GridSearchCV(KNeighborsClassifier(), param_grid_knn, cv=5, scoring='f1')
grid_search_knn.fit(X_train, y_train)

# %% [markdown]
# ## Random Forest GridSearch

# %%
# TODO
# Complete this part by analyzing how it id done for Logistic Regression

# %% [markdown]
# ## Final Evaluation (On the TestSet)

# %%
# TODO

# %% [markdown]
# ## Analysis & Reporting

# %%
# TODO
